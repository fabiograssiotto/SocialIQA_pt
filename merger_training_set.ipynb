# %% [markdown]
# ## This file implements a merger for the training sets results.

# %% [markdown]
# ### Install Libraries

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\fabio.grassiotto\research\venv\ml\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\fabio.grassiotto\research\venv\ml\lib\site-packages (from pandas) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\fabio.grassiotto\research\venv\ml\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\fabio.grassiotto\research\venv\ml\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\fabio.grassiotto\research\venv\ml\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\fabio.grassiotto\research\venv\ml\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Imports

# %%
import os
import pandas as pd

# %% [markdown]
# ### Merge training dataset results (PT)

# %%
# List of CSV file paths
folder_path = "translated/final/train_sets"
file_paths = ['train_1.csv', 'train_2.csv', 'train_3.csv', 'train_4.csv', 'train_5.csv', 'train_6.csv', 'train_7.csv']

# Initialize an empty list to store the DataFrames
dataframes = []

# Read each CSV file and append to the list
for file in file_paths:
    df = pd.read_csv(folder_path + "/" + file)
    dataframes.append(df)

# Concatenate the DataFrames row-wise
df_train = pd.concat(dataframes, ignore_index=True)
df_train = df_train.drop(columns=['Unnamed: 0'])

# %%
df_train
# Out:
#                                                  context  \
# 0      Embora tivesse realizado trabalho doméstico pa...
# 1      Depois da escola, o Casey conheceu a amiga num...
# 2      Jesse chegou rapidamente à mãe e a mãe lhes di...
# 3      A Robin sabia que o Kai queria que ela gostass...
# 4      Addison dormiu bem ontem à noite depois de jog...
# ...                                                  ...
# 33405  O Quinn tinha um trabalho de pesquisa para a m...
# 33406  Ash fez alguns novos amigos no primeiro dia na...
# 33407  Carson decidiu experimentar encontros online, ...
# 33408  Jesse colocou o peru na geladeira para que ele...
# 33409  Robin saltou descuidadamente para a cama, mas ...
#
#                                                 question  \
# 0                     O que Jesse quer fazer em seguida?
# 1                               Porque fez o Casey isto?
# 2                         Como Jesse se sentiria depois?
# 3                         Porque é que a Robin fez isto?
# 4                       Porque é que a Addison fez isto?
# ...                                                  ...
# 33405                 O que quer o Quinn fazer a seguir?
# 33406                       Porque é que o Ash fez isto?
# 33407  O que é que o Carson precisa de fazer antes di...
# 33408        Como os outros se sentiriam como resultado?
# 33409                          Como descreveria a Robin?
#
#                                    answerA  \
# 0       Leia o serviço de casa para Skylar
# 1            ter uma boa ideia do material
# 2                             desperdícios
# 3        Pagou-lhe para dizer que gostava.
# 4                  Recupera a sua energia.
# ...                                    ...
# 33405        Espera até ao minuto do elast
# 33406  tomar uma coca com os novos amigos.
# 33407                Casem-se antes disto.
# 33408                             com fome
# 33409                            atencioso
#
#                                                answerB  \
# 0                           Ajuda de acabamento Skylar
# 1                                 brincar com um amigo
# 2                              que são uma criança boa
# 3      Ela nunca gostou muito do Kai ou da moda dela .
# 4                                    bateu um home run
# ...                                                ...
# 33405                  Começar o projeto à meia-noite.
# 33406                     Faz HW com o seu novo amigo.
# 33407                    Decidir até agora antes disto
# 33408                                          sedento
# 33409                                      desajeitado
#
#                                                  answerC correct
# 0                                      skip seus estudos       B
# 1                        Bebam um copo e vão-se embora .       A
# 2                              que a mãe sempre os chama       B
# 3      Ela sabia que o Kai queria que a Robin gostass...       C
# 4                                                - Não .       A
# ...                                                  ...     ...
# 33405                  Tentar terminar o trabalho deles.       C
# 33406                                       ser sociável       C
# 33407                       Acabar a escola antes disto.       B
# 33408                                        Antecipação       C
# 33409                             Com o coração partido.       B
#
# [33410 rows x 6 columns]

# %%
# Write to filesystem
df_train.to_csv("translated/final/train.csv")

# %% [markdown]
# ### Merge Ranking results

# %%
# List of CSV file paths
folder_path = "rankings/train_sets"
file_paths = ['train_1_rankings.csv', 'train_2_rankings.csv', 'train_3_rankings.csv',
              'train_4_rankings.csv', 'train_5_rankings.csv', 'train_6_rankings.csv', 'train_7_rankings.csv']

# Initialize an empty list to store the DataFrames
dataframes = []

# Read each CSV file and append to the list
for file in file_paths:
    df = pd.read_csv(folder_path + "/" + file)
    dataframes.append(df)

# Concatenate the DataFrames row-wise
df_train_rankings = pd.concat(dataframes, ignore_index=True)
df_train_rankings = df_train_rankings.drop(columns=['Unnamed: 0'])

# %%
df_train_rankings
# Out:
#        MarianMT  Unicamp_T5  NLLB_1.3b
# 0            82          90         88
# 1            75          60         80
# 2            85          90         80
# 3            80          60         90
# 4            75          60         85
# ...         ...         ...        ...
# 33405        60          40         80
# 33406        85          80         90
# 33407        75          80         90
# 33408        90          70         85
# 33409        70          20         80
#
# [33410 rows x 3 columns]

# %%
# Write to filesystem
df_train_rankings.to_csv("rankings/train_rankings.csv")
